# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression , LinearRegression
from sklearn.feature_selection import VarianceThreshold
from sklearn.pipeline import make_pipeline

# %% [markdown]
# #### Chargement du jeu de donnée

# %%
fraud = pd.read_csv("fraud_data.csv")

# %% [markdown]
# #### I. EDA

# %%
sns.countplot(x = fraud.Class)
# Out:
# <AxesSubplot:xlabel='Class', ylabel='count'>

# %%
fraud.Class.value_counts(normalize=True)
# Out:
# 0    0.983589
# 1    0.016411
# Name: Class, dtype: float64

# %%
fraud.dtypes.value_counts()
# Out:
# float64    29
# int64       1
# dtype: int64

# %%
plt.figure
for col in fraud.columns: 
    _ = sns.distplot(fraud[col])
    plt.show()
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/env_tensorflow/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/env_tensorflow/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# ## preprocessing

# %%
## separtion du jeud donnee 
Dtrain, Dtest = train_test_split(fraud, test_size=0.2)
X_train , y_train = Dtrain.drop(columns=["Class"]), Dtrain.Class
X_test , y_test = Dtest.drop(columns=["Class"]), Dtest.Class

# %%
# feature selection 
selector = VarianceThreshold(threshold=0.5)
selector.fit(X_train)
X_train_select = selector.transform(X_train)

# %%
# normaliser le jeu de donnée 
scaler = StandardScaler()
X_train_scaler = scaler.fit_transform(X_train_select)

# Utilisation de la class PolynomialFeatures 
poly = PolynomialFeatures(degree=2)
poly.fit(X_train_scaler)
X_train_scaler =  poly.transform(X_train_scaler)

# %%
#### Creation du model 
model = LogisticRegression()
model.fit(X_train_scaler, y_train)
model.score(X_train_scaler, y_train)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/env_tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.9983865391264262

# %% [markdown]
# #### Erreur de generalisation du model

# %%
#feature selction 

X_test_select = selector.transform(X_test)
# normalisation du jeu de test 
X_test_scaler = scaler .transform(X_test_select)

# PolynomialFeatures dans le jeu de test 

X_test_scaler = poly.transform(X_test_scaler)

# %%
model.score(X_test_scaler, y_test)
# Out:
# 0.9958515787047707

# %%
model.get_params()
# Out:
# {'C': 1.0,
#  'class_weight': None,
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'l1_ratio': None,
#  'max_iter': 100,
#  'multi_class': 'auto',
#  'n_jobs': None,
#  'penalty': 'l2',
#  'random_state': None,
#  'solver': 'lbfgs',
#  'tol': 0.0001,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# #### Utilisation des Pipline

# %%
iris = sns.load_dataset("iris")
X, y = iris.drop(columns=["species"], axis=1),  iris.species

# %%
# Normalisation 
scaler = StandardScaler()
X_scaler = scaler.fit_transform(X, y)

# polynomialFeatures 
poly = PolynomialFeatures(degree=1)
X_scaler = poly.fit_transform(X_scaler)

# %%
model_L = LogisticRegression()
model_L.fit(X_scaler, y)
model_L.score(X_scaler, y)
# Out:
# 0.9733333333333334

# %%
model = make_pipeline(StandardScaler(), PolynomialFeatures(),
                                        VarianceThreshold(), 
                                        LogisticRegression()
                                        )
                                        

params_dico = {'variancethreshold__threshold':np.linspace(0,1), 
    'polynomialfeatures__degree': [1,2,3]
}

# %%
grid = GridSearchCV(model, param_grid=params_dico)
grid.fit(X, y)
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                                        ('polynomialfeatures',
#                                         PolynomialFeatures()),
#                                        ('variancethreshold',
#                                         VarianceThreshold()),
#                                        ('logisticregression',
#                                         LogisticRegression())]),
#              param_grid={'polynomialfeatures__degree': [1, 2, 3],
#                          'variancethreshold__threshold': array([0.        , 0.02040816, 0.04081633, 0.06122449, 0.08163265,
#        0.1020408...
#        0.30612245, 0.32653061, 0.34693878, 0.36734694, 0.3877551 ,
#        0.40816327, 0.42857143, 0.44897959, 0.46938776, 0.48979592,
#        0.51020408, 0.53061224, 0.55102041, 0.57142857, 0.59183673,
#        0.6122449 , 0.63265306, 0.65306122, 0.67346939, 0.69387755,
# ...

# %%
model = grid.best_estimator_

# %%
model.score(X, y)
# Out:
# 0.98
